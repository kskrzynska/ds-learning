# %% [markdown]
# <a href="https://colab.research.google.com/github/kskrzynska/ds-learning/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Zadanie 1

# %%
waga = 70

# %%
wzrost = 1.75

# %%
BMI = waga / (wzrost ** 2 )

# %%
BMI
# Out:
# 22.857142857142858

# %%
zaokrąglone = round(BMI, 2)

# %%
print(f"BMI zaokrąglone: {zaokrąglone}")
# Out:
# BMI zaokrąglone: 22.86

# %%
if BMI <= 18.5:
    print("Niedowaga")
if BMI > 18.5 and BMI < 25:
    print("Norma")
if BMI >= 25:
    print("Nadwaga")
# Out:
# Norma

# %% [markdown]
# Zadanie 2

# %%
Celsius = 23.5

# %%
Fahrenheit = (Celsius * 9/5) + 32

# %%
Kelvin = Celsius + 273.15

# %%
print(f"{Celsius:.1f}°C = {Fahrenheit:.1f}°F = {Kelvin:.1f} K")
# Out:
# 23.5°C = 74.3°F = 296.6 K

# %% [markdown]
# Zadanie 3

# %%
całkowita_liczba_probek = 1000

# %%
trening = 0.7 * całkowita_liczba_probek

# %%
walidacja = 0.15 * całkowita_liczba_probek

# %%
test = 0.15 * całkowita_liczba_probek

# %%
print(f"Zbiór treningowy: {trening}")
print(f"Zbiór walidacyjny: {walidacja}")
print(f"Zbiór testowy: {test}")
# Out:
# Zbiór treningowy: 700.0
# Zbiór walidacyjny: 150.0
# Zbiór testowy: 150.0

# %%
print(f"Suma: {trening + walidacja + test}")
# Out:
# Suma: 1000.0

# %% [markdown]
# Zadanie 4

# %%
Nazwa_raw = " PATIENT_age_YEARS "

# %%
Nazwa_clean = Nazwa_raw.strip()

# %%
print(Nazwa_clean)
# Out:
# PATIENT_age_YEARS

# %%
print(Nazwa_clean.lower())
# Out:
# patient_age_years

# %%
Nazwa_standard = Nazwa_clean.lower().replace("_", " ")

# %%
print(Nazwa_standard)
# Out:
# patient age years

# %%
Nazwa_pelna = Nazwa_standard.title()

# %%
print(Nazwa_pelna)
# Out:
# Patient Age Years

# %% [markdown]
# Zadanie 5

# %%
sciezka = "data/processed/train_fold_03_normalized.csv"

# %%
czesci = sciezka.split("/")

# %%
print(f"Części ścieżki: {czesci}")
# Out:
# Części ścieżki: ['data', 'processed', 'train_fold_03_normalized.csv']

# %%
nazwa_pliku = czesci[-1]

# %%
print(f"Nazwa pliku: {nazwa_pliku}")
# Out:
# Nazwa pliku: train_fold_03_normalized.csv

# %%
folder = czesci[1]

# %%
elementy = nazwa_pliku.split("_")

# %%
typ_zbioru = elementy[0]

# %%
numer_fold = elementy[2]

# %%
komponent = nazwa_pliku.split(".")

# %%
format_pliku = komponent[1]

# %%
print(f"Folder: {folder}")
print(f"Typ zbioru: {typ_zbioru}")
print(f"Numer fold: {numer_fold}")
print(f"Format pliku: {format_pliku}")
# Out:
# Folder: processed
# Typ zbioru: train
# Numer fold: 03
# Format pliku: csv

# %% [markdown]
# Zadanie 6

# %%
model_type = "X"
accuracy = 0.9234
precision = 0.8891
recall = 0.9456

# %%
raport_fstring = f"Model: {model_type}, Accuracy: {accuracy:.2%}, Precision: {precision:.2%}, Recall: {recall:.2%}"

# %%
print(raport_fstring)
# Out:
# Model: X, Accuracy: 92.34%, Precision: 88.91%, Recall: 94.56%

# %%
headers = ["Model", "Accuracy", "Precision", "Recall"]
print(f"{headers[0]:<20} {headers[1]:>10} {headers[2]:>10} {headers[3]:>10}")
print(f"{model_type:<20} {accuracy:>10.2%} {precision:>10.2%} {recall:>10.2%}")
# Out:
# Model                  Accuracy  Precision     Recall
# X                        92.34%     88.91%     94.56%

# %% [markdown]
# Zadanie 9

# %%
wartosc = 75
minimum_w_kolumnie = 50
maximum_w_kolumnie = 100

# %%
normalized_75 = (75 - 50) / (100 - 50)

# %%
print(normalized_75)
# Out:
# 0.5

# %%
normalized_50 = (50 - 50) / (100 - 50)

# %%
print(normalized_50)
# Out:
# 0.0

# %%
normalized_100 = (100 - 50) / (100 - 50)

# %%
print(normalized_100)
# Out:
# 1.0

# %%
normalized_62_5 = (62.5 - 50) / (100 - 50)

# %%
print(normalized_62_5)
# Out:
# 0.25

# %%
if normalized_62_5 >= 0 and normalized_62_5 <= 1:
  print("Wynik mieści się w [0,1]")
else:
  print:("Wynik nie mieści się w [0,1]")
# Out:
# Wynik mieści się w [0,1]

# %%
if normalized_100 >= 0 and normalized_100 <= 1:
  print("Wynik mieści się w [0,1]")
else:
  print:("Wynik nie mieści się w [0,1]")
# Out:
# Wynik mieści się w [0,1]

# %%
if normalized_50 >= 0 and normalized_50 <= 1:
  print("Wynik mieści się w [0,1]")
else:
  print:("Wynik nie mieści się w [0,1]")
# Out:
# Wynik mieści się w [0,1]

# %%
if normalized_75 >= 0 and normalized_75 <= 1:
  print("Wynik mieści się w [0,1]")
else:
  print:("Wynik nie mieści się w [0,1]")
# Out:
# Wynik mieści się w [0,1]

# %%
wartosc_oryginalna = [75, 50, 100, 62.5]

# %%
wartosc_znormalizowana = [normalized_75, normalized_50, normalized_100, normalized_62_5]

# %%
print(f"Wartość oryginalna: {wartosc_oryginalna} | Wartość znormalizowana: {wartosc_znormalizowana}")
# Out:
# Wartość oryginalna: [75, 50, 100, 62.5] | Wartość znormalizowana: [0.5, 0.0, 1.0, 0.25]

# %%
print("Wartość oryginalna | Wartość znormalizowana")
print("-------------------------------------------")

for i in range(len(wartosc_oryginalna)):
    print(f"{wartosc_oryginalna[i]:18} | {wartosc_znormalizowana[i]:.2f}")
# Out:
# Wartość oryginalna | Wartość znormalizowana
# -------------------------------------------
#                 75 | 0.50
#                 50 | 0.00
#                100 | 1.00
#               62.5 | 0.25

# %% [markdown]
# Zadanie 11

# %%
learning_rate = 0.01
batch_size = 64
epochs = 100
dropout = 0.5

# %%
if 0 <= learning_rate <= 1:
    print("learning_rate: OK")
else:
    print("learning_rate: Błąd - wartość musi być w zakresie 0-1")
# Out:
# learning_rate: OK

# %%
import math

# %%
if batch_size > 0 and math.log2(batch_size) == int(math.log2(batch_size)):
    print("batch_size: OK")
else:
    print("batch_size: Błąd - musi być potęgą 2")
# Out:
# batch_size: OK

# %%
if 0 < epochs < 1000:
    print("epochs: OK")
else:
    print("epochs: Błąd - musi być większe od 0 i mniejsze od 1000")
# Out:
# epochs: OK

# %%
if 0 <= dropout <= 1:
    print("dropout: OK")
else:
    print("dropout: Błąd - wartość musi być w zakresie 0-1")
# Out:
# dropout: OK

# %% [markdown]
# Zadanie 12

# %%
Liczba_probek = 50000
Batch_size = 128
Liczba_epok = 50
Czas_na_jeden_batch = 0.15

# %%
pelne_batche = Liczba_probek // Batch_size

# %%
pelne_batche
# Out:
# 390

# %%
pozostale_probki = Liczba_probek % Batch_size

# %%
print(pozostale_probki)
# Out:
# 80

# %%
if pozostale_probki > 0:
  batche_na_epoke = pelne_batche + 1
else: batche_na_epoke = pelne_batche

# %%
liczba_batchów = batche_na_epoke * Liczba_epok

# %%
liczba_batchów
# Out:
# 19550

# %%
czas_w_sekundach = liczba_batchów * Czas_na_jeden_batch

# %%
print(czas_w_sekundach)
# Out:
# 2932.5

# %%
godziny = int(czas_w_sekundach // 3600)

# %%
godziny
# Out:
# 0

# %%
minuty = int((czas_w_sekundach % 3600) // 60)

# %%
minuty
# Out:
# 48

# %%
sekundy = int(czas_w_sekundach % 60)

# %%
sekundy
# Out:
# 52

# %%
print(f"Szacowany czas: {godziny} h {minuty} min {sekundy} s")
# Out:
# Szacowany czas: 0 h 48 min 52 s

# %% [markdown]
# Zadanie 15

# %%
Waga_1 = 65.5
Waga_2 = 78.2
Waga_3 = 54.8
Waga_4 = 92.1
Waga_5 = 70.0

# %%
średnia = (Waga_1 + Waga_2 + Waga_3 + Waga_4 + Waga_5) / 5

# %%
print(średnia)
# Out:
# 72.12

# %%
odch_1 = (Waga_1 - średnia) ** 2
odch_2 = (Waga_2 - średnia) ** 2
odch_3 = (Waga_3 - średnia) ** 2
odch_4 = (Waga_4 - średnia) ** 2
odch_5 = (Waga_5 - średnia) ** 2

# %%
wariancja = (odch_1 + odch_2 + odch_3 + odch_4 + odch_5) / 5

# %%
odchylenie_std = math.sqrt(wariancja)

# %%
print(f"Odchylenie standardowe: {odchylenie_std:.2f}")
# Out:
# Odchylenie standardowe: 12.53

# %%
z_1 = (Waga_1 - średnia) / odchylenie_std

# %%
print(z_1)
# Out:
# -0.5285126362284744

# %%
z_2 = (Waga_2 - średnia) / odchylenie_std

# %%
print(z_2)
# Out:
# 0.485401333575396

# %%
z_3 = (Waga_3 - średnia) / odchylenie_std

# %%
print(z_3)
# Out:
# -1.3827551147246486

# %%
z_4 = (Waga_4 - średnia) / odchylenie_std

# %%
print(z_4)
# Out:
# 1.5951181981638831

# %%
z_5 = (Waga_5 - średnia) / odchylenie_std

# %%
print(z_5)
# Out:
# -0.1692517807861582
