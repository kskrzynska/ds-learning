# %% [markdown]
# <a href="https://colab.research.google.com/github/kskrzynska/ds-learning/blob/main/pracadomowa6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Zadanie 1

# %%
student = {
    'imie': 'Kamil',
    'nazwisko': 'Nowak',
    'wiek': 22,
    'kierunek': 'informatyka'
    }

# %%
student['email'] = 'kamil.nowak@edu.pl'

# %%
student['wiek'] = 23

# %%
print(f"Student: {student['imie']} {student['nazwisko']} ({student['wiek']} lata), "
      f"kierunek: {student['kierunek']}, email: {student['email']}.")
# Out:
# Student: Kamil Nowak (23 lata), kierunek: informatyka, email: kamil.nowak@edu.pl.

# %%
klucze = list(student.keys())

# %%
print(klucze)
# Out:
# ['imie', 'nazwisko', 'wiek', 'kierunek', 'email']

# %%
wartosci = list(student.values())

# %%
print(wartosci)
# Out:
# ['Kamil', 'Nowak', 23, 'informatyka', 'kamil.nowak@edu.pl']

# %% [markdown]
# Zadanie 2

# %%
konfig = {'lr': 0.01, 'epochs': 100, 'optimizer': 'adam'}

# %%
print(konfig.get('lr'))
# Out:
# 0.01

# %%
print(konfig.get('momentum'))
# Out:
# None

# %%
print(konfig.get('momentum', '0.9'))
# Out:
# 0.9

# %%
print('batch_size' in konfig)
# Out:
# False

# %% [markdown]
# Zadanie 3

# %%
metryki = {
    'accuracy': 0.94,
    'precision': 0.91,
    'recall': 0.89,
    'f1_score': 0.90
}

# %%
print(f"Najwyższa wartość metryki: {max(metryki.values())}")
# Out:
# Najwyższa wartość metryki: 0.94

# %%
print(f"Najniższa wartość metryki: {min(metryki.values())}")
# Out:
# Najniższa wartość metryki: 0.89

# %%
print(f"Klucze posortowane alfabetycznie: {sorted(metryki.keys())}")
# Out:
# Klucze posortowane alfabetycznie: ['accuracy', 'f1_score', 'precision', 'recall']

# %%
print(f"Wartości posortowane rosnąco: {sorted(metryki.values())}")
# Out:
# Wartości posortowane rosnąco: [0.89, 0.9, 0.91, 0.94]

# %% [markdown]
# Zadanie 4

# %%
jezyki = {'Python', 'R', 'SQL', 'Python', 'Julia', 'R', 'Python', 'Scala', 'SQL'}

# %%
unikalne = set(jezyki)

# %%
print(unikalne)
# Out:
# {'Julia', 'R', 'Scala', 'SQL', 'Python'}

# %%
jezyki.update(('Go', 'Rust'))

# %%
print('Python' in jezyki)
# Out:
# True

# %%
print('Fortran' in jezyki)
# Out:
# False

# %%
print('Julia' in jezyki)
# Out:
# True

# %%
jezyki.discard('Scala')

# %%
print(jezyki)
# Out:
# {'Go', 'go', 'java', 'SQL', 'Rust', 'R', 'Julia', 'Python'}

# %% [markdown]
# Zadanie 5

# %%
grupa_a = {'python', 'pandas', 'numpy', 'sql', 'tableau'}
grupa_b = {'python', 'r', 'sql', 'ggplot2', 'dplyr'}

# %%
suma1 = grupa_a | grupa_b

# %%
wspolne1 = grupa_a & grupa_b

# %%
roznica = grupa_a - grupa_b

# %%
xor1 = grupa_a ^ grupa_b

# %%
print(suma1)
print(wspolne1)
print(roznica)
print(xor1)
# Out:
# {'r', 'sql', 'python', 'pandas', 'tableau', 'dplyr', 'numpy', 'ggplot2'}
# {'python', 'sql'}
# {'pandas', 'numpy', 'tableau'}
# {'dplyr', 'numpy', 'r', 'ggplot2', 'pandas', 'tableau'}

# %%
print(grupa_a.isdisjoint(grupa_b))
# Out:
# False

# %% [markdown]
# Zadanie 6

# %%
wymiary = (1920, 1080)

# %%
szerokosc, wysokosc = wymiary

# %%
print(f"szerokosc = {szerokosc}, wysokosc = {wysokosc}")
# Out:
# szerokosc = 1920, wysokosc = 1080

# %%
print(f"Rozdzielczość = {szerokosc}x{wysokosc}")
# Out:
# Rozdzielczość = 1920x1080

# %%
samotny = (42,)

# %%
type(samotny)
# Out:
# tuple

# %%
samotny[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7728/1323611435.py in <cell line: 0>()
# ----> 1 samotny[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# (nie można nadpisywać krotek)

# %%
nowa_krotka = samotny + (100, 200)

# %%
print(f"Wypisanie nowej krotki: {nowa_krotka}")
# Out:
# Wypisanie nowej krotki: (42, 100, 200)

# %% [markdown]
# Zadanie 7

# %%
pracownik = ('Julia', 'Wiśniewska', 28, 'Data Analyst', 8500.00)

# %%
imie = pracownik[0]

# %%
nazwisko = pracownik[1]

# %%
wiek = pracownik[2]

# %%
stanowisko = pracownik[3]

# %%
pensja = pracownik[4]

# %%
print(f"{imie} {nazwisko} ({wiek}) - {stanowisko}, pensja: {pensja}zł.")
# Out:
# Julia Wiśniewska (28) - Data Analyst, pensja: 8500.0zł.

# %%
imie, *reszta = pracownik

# %%
print(imie)
# Out:
# Julia

# %%
print(reszta)
# Out:
# ['Wiśniewska', 28, 'Data Analyst', 8500.0]

# %% [markdown]
# Zadanie 8

# %%
sprzedaz = {
(2024, 'Q1'): 120_000,
(2024, 'Q2'): 140_000,
(2024, 'Q3'): 135_000,
(2024, 'Q4'): 160_000
}

# %%
print(sprzedaz[(2024, 'Q2')])
# Out:
# 140000

# %%
sprzedaz[(2025, 'Q1')] = 130_000

# %%
print("Najwyższa sprzedaż:", max(sprzedaz.values()))
# Out:
# Najwyższa sprzedaż: 160000

# %%
print("Najniższa sprzedaż:", min(sprzedaz.values()))
# Out:
# Najniższa sprzedaż: 120000

# %%
print("Łączna sprzedaż:", sum(sprzedaz.values()))
# Out:
# Łączna sprzedaż: 685000

# %%
print("Liczba kwartałów:", len(sprzedaz))
# Out:
# Liczba kwartałów: 5

# %% [markdown]
# Zadanie 10

# %%
dataset_a = {'wiek', 'plec', 'miasto', 'dochod', 'wyksztalcenie', 'stan_cywilny'}
dataset_b = {'wiek', 'plec', 'miasto', 'pensja', 'stanowisko', 'staz'}

# %%
wspolne = dataset_a & dataset_b

# %%
tylko_dataset_a = dataset_a - dataset_b

# %%
tylko_dataset_b = dataset_b - dataset_a

# %%
suma = dataset_a | dataset_b

# %%
xor = dataset_a ^ dataset_b

# %%
print({'wiek', 'plec'}.issubset(wspolne))
# Out:
# True

# %% [markdown]
# Zadanie 16

# %%
sprzedaz = {
(2024, 'Q1'): 120_000,
(2024, 'Q2'): 145_000,
(2024, 'Q3'): 138_000,
(2024, 'Q4'): 167_000,
(2025, 'Q1'): 130_000,
(2025, 'Q2'): 155_000,
(2025, 'Q3'): 149_000
}

# %%
print('Całkowita sprzedaż:', sum(sprzedaz.values()))
# Out:
# Całkowita sprzedaż: 1004000

# %%
print("Najniższa sprzedaż:", min(sprzedaz.values()))
# Out:
# Najniższa sprzedaż: 120000

# %%
print("Najwyższa sprzedaż:", max(sprzedaz.values()))
# Out:
# Najwyższa sprzedaż: 167000

# %%
klucz_max = max(sprzedaz, key=sprzedaz.get)

# %%
rok_max, kw_max = klucz_max

# %%
print(f"Najwyższa sprzedaż: {rok_max} {kw_max} - {max(sprzedaz.values())}")
# Out:
# Najwyższa sprzedaż: 2024 Q4 - 167000

# %%
posortowane_klucze = sorted(sprzedaz, key=sprzedaz.get, reverse=True)

# %%
print(posortowane_klucze[0])
# Out:
# (2024, 'Q4')

# %%
print(posortowane_klucze[1])
# Out:
# (2025, 'Q2')

# %%
print(posortowane_klucze[2])
# Out:
# (2025, 'Q3')

# %%
unikalne_lata = {2024, 2025}
